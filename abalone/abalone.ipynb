# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# # Notebook configurations

# %%
# %matplotlib inline

# %% [markdown]
# # Graphs

# %%
from seaborn import set_style
set_style("darkgrid")
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data to JupyterLab

# %%
data = pd.read_csv(r"abalone.csv")
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
data.groupby("Rings").Rings.count()
# Out:
# Rings
# 1       1
# 2       1
# 3      15
# 4      57
# 5     115
# 6     259
# 7     391
# 8     568
# 9     689
# 10    634
# 11    487
# 12    267
# 13    203
# 14    126
# 15    103
# 16     67
# 17     58
# 18     42
# 19     32
# 20     26
# 21     14
# 22      6
# 23      9
# 24      2
# 25      1
# 26      1
# 27      2
# 29      1
# Name: Rings, dtype: int64

# %% [markdown]
# # Distribution of 'Rings' data

# %%
sns.set(color_codes=True)

# %%
sns.distplot(data.Rings)
# Out:
# C:\Users\rjhcl\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [markdown]
# # Distribution of 'Length' data

# %%
sns.distplot(data.Length, bins=100)
# Out:
# C:\Users\rjhcl\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %% [markdown]
# # Scatterplot for 'Rings' and 'Diameter' data

# %%
sns.jointplot(x="Rings", y="Diameter", data=data)

# %% [markdown]
# # Split data into inputs and outputs

# %%
X, y = data.drop('Rings', axis=1), data.Rings

# %%
X
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 8 columns]

# %% [markdown]
# # Define categorical and numerical features

# %%
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object', 'bool']).columns

# %%
numeric_features
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight'],
#       dtype='object')

# %%
categorical_features
# Out:
# Index(['Sex'], dtype='object')

# %% [markdown]
# # Transform columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

preprocessor = ColumnTransformer(
    transformers=[
        ('categorical', OneHotEncoder(), categorical_features),
        ('numeric', MinMaxScaler(), numeric_features)
    
])

X = preprocessor.fit_transform(X)

# %%
X
# Out:
# array([[0.        , 0.        , 1.        , ..., 0.15030262, 0.1323239 ,
#         0.14798206],
#        [0.        , 0.        , 1.        , ..., 0.06624075, 0.06319947,
#         0.06826109],
#        [1.        , 0.        , 0.        , ..., 0.17182246, 0.18564845,
#         0.2077728 ],
#        ...,
#        [0.        , 0.        , 1.        , ..., 0.3527236 , 0.37788018,
#         0.30543099],
#        [1.        , 0.        , 0.        , ..., 0.35642233, 0.34298881,
#         0.29347285],
#        [0.        , 0.        , 1.        , ..., 0.63517149, 0.49506254,
#         0.49177877]])

# %% [markdown]
# # Put data to user friendly view -DataFrame

# %%
dataset = pd.DataFrame({'Female': X[:, 0], 
                        'Infant': X[:, 1],
                        'Male': X[:, 2],
                        'Length': X[:, 3],
                        'Diameter': X[:, 4], 
                        'Height': X[:, 5],
                        'Whole weight': X[:, 6],
                        'Shucked weight': X[:, 7],
                        'Viscera weight': X[:, 8],
                        'Shell weight': X[:, 9]})

# %%
dataset
# Out:
#       Female  Infant  Male    Length  Diameter    Height  Whole weight  \
# 0        0.0     0.0   1.0  0.513514  0.521008  0.084071      0.181335
# 1        0.0     0.0   1.0  0.371622  0.352941  0.079646      0.079157
# 2        1.0     0.0   0.0  0.614865  0.613445  0.119469      0.239065
# 3        0.0     0.0   1.0  0.493243  0.521008  0.110619      0.182044
# 4        0.0     1.0   0.0  0.344595  0.336134  0.070796      0.071897
# ...      ...     ...   ...       ...       ...       ...           ...
# 4172     1.0     0.0   0.0  0.662162  0.663866  0.146018      0.313441
# 4173     0.0     0.0   1.0  0.695946  0.647059  0.119469      0.341420
# 4174     0.0     0.0   1.0  0.709459  0.705882  0.181416      0.415796
# 4175     1.0     0.0   0.0  0.743243  0.722689  0.132743      0.386931
# 4176     0.0     0.0   1.0  0.858108  0.840336  0.172566      0.689393
#
#       Shucked weight  Viscera weight  Shell weight
# 0           0.150303        0.132324      0.147982
# 1           0.066241        0.063199      0.068261
# 2           0.171822        0.185648      0.207773
# 3           0.144250        0.149440      0.152965
# 4           0.059516        0.051350      0.053313
# ...              ...             ...           ...
# 4172        0.248151        0.314022      0.246637
# 4173        0.294553        0.281764      0.258097
# 4174        0.352724        0.377880      0.305431
# 4175        0.356422        0.342989      0.293473
# 4176        0.635171        0.495063      0.491779
#
# [4177 rows x 10 columns]

# %%
dataset.describe()
# Out:
#             Female       Infant         Male       Length     Diameter  \
# count  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000
# mean      0.312904     0.321283     0.365813     0.606746     0.593078
# std       0.463731     0.467025     0.481715     0.162288     0.166790
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.506757     0.495798
# 50%       0.000000     0.000000     0.000000     0.635135     0.621849
# 75%       1.000000     1.000000     1.000000     0.729730     0.714286
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#             Height  Whole weight  Shucked weight  Viscera weight  Shell weight
# count  4177.000000   4177.000000     4177.000000     4177.000000   4177.000000
# mean      0.123466      0.292808        0.241000        0.237121      0.236503
# std       0.037015      0.173681        0.149269        0.144324      0.138717
# min       0.000000      0.000000        0.000000        0.000000      0.000000
# 25%       0.101770      0.155658        0.124412        0.122449      0.128052
# 50%       0.123894      0.282451        0.225286        0.224490      0.231689
# 75%       0.146018      0.407650        0.336920        0.332456      0.326358
# max       1.000000      1.000000        1.000000        1.000000      1.000000
